# %%
import pandas as pd
import numpy as np

from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
# !pip install geopy

# %%
# 1 m2 to ft2
m2_to_ft2 = 10.764

# url for different datasets
sales_consideration_url = "http://www.rvd.gov.hk/datagovhk/7.3.csv"
secondary_avg_price_district_url = "http://www.rvd.gov.hk/datagovhk/1.2M.csv"
vacancy_rate_url = "http://www.rvd.gov.hk/datagovhk/Private_Domestic-Vacancy.csv"

# %% [markdown]
# ### Primary and secondary sales amount and consideration by year

# %%
sales_considerations_df = pd.read_csv(sales_consideration_url, skiprows = 1, encoding = "utf-8")

# %%
# done
sales_considerations_df.head()
# Out:
#      Month  Primary Sales Number  Primary Sales Consideration  \
# 0  01-2002                  2718                         8218
# 1  02-2002                  1506                         4305
# 2  03-2002                  1709                         4190
# 3  04-2002                  2543                         6516
# 4  05-2002                  2257                         5844
#
#    Secondary Sales Number  Secondary Sales Consideration
# 0                    5129                           9966
# 1                    4189                           8070
# 2                    3741                           6795
# 3                    4866                           8739
# 4                    5068                          11097

# %%
sales_considerations_df.to_csv("sales_numbers_with_considerations.csv", index = False, encoding = "utf-8")

# %% [markdown]
# ### Secondary consideration by district

# %%
secondary_avg_price_district_df = pd.read_csv(secondary_avg_price_district_url, skiprows = 1, encoding = "utf-8")

# %%
secondary_avg_price_district_df.head()
# Out:
#      Month  Class A Hong Kong Class A Hong Kong - Remarks  Class A Kowloon  \
# 0  01-1999              42663                         NaN            36842
# 1  02-1999              43068                         NaN            35834
# 2  03-1999              42683                         NaN            36731
# 3  04-1999              43223                         NaN            36543
# 4  05-1999              43316                         NaN            36449
#
#   Class A Kowloon - Remarks  Class A New Territories  \
# 0                       NaN                    36679
# 1                       NaN                    36802
# 2                       NaN                    36992
# 3                       NaN                    36485
# 4                       NaN                    38035
#
#   Class A New Territories - Remarks  Class B Hong Kong  \
# 0                               NaN              50141
# 1                               NaN              47950
# ...

# %%
# include only columns with consideration without remarks columns
col_list = []

for col in secondary_avg_price_district_df.columns:
    if 'remarks' not in col.lower():
        col_list.append(col)

# %%
result_df = secondary_avg_price_district_df[col_list]

# %%
result_df.tail()
# Out:
#        Month  Class A Hong Kong  Class A Kowloon  Class A New Territories  \
# 322  11-2025             135832           116077                   112115
# 323  12-2025             136878           118338                   115164
# 324  01-2026             138129           122677                   116994
# 325  02-2026             141467           127581                   121357
# 326  03-2026             140442           128140                   123740
#
#      Class B Hong Kong  Class B Kowloon  Class B New Territories  \
# 322             141364           130928                   109271
# 323             139422           131141                   107333
# 324             143784           129117                   110327
# 325             145780           133838                   113632
# 326             148636           136937                   113073
#
#      Class C Hong Kong  Class C Kowloon  Class C New Territories  \
# ...

# %%
# unpivot the dataframe to have a long format
result_melt_df = pd.melt(result_df, id_vars = ['Month'], var_name = 'property_category', value_name = 'secondary_consideration')

# %%
class_filter = ['Class A', 'Class B']
df_test = result_melt_df.head(0)

for class_str in class_filter:
    df_temp = result_melt_df[result_melt_df['property_category'].str.contains(class_str)]
    df_test = pd.concat([df_test, df_temp])

# %%
df_test.head()
# Out:
#      Month  property_category secondary_consideration
# 0  01-1999  Class A Hong Kong                   42663
# 1  02-1999  Class A Hong Kong                   43068
# 2  03-1999  Class A Hong Kong                   42683
# 3  04-1999  Class A Hong Kong                   43223
# 4  05-1999  Class A Hong Kong                   43316

# %%
result_melt_df.tail()
# Out:
#         Month        property_category secondary_consideration
# 4900  11-2025  Class E New Territories                  100413
# 4901  12-2025  Class E New Territories                  100185
# 4902  01-2026  Class E New Territories                   84710
# 4903  02-2026  Class E New Territories                   97216
# 4904  03-2026  Class E New Territories                  103942

# %%
# separate property category into class and district columns, and remove prefix and suffix spaces
result_melt_df['district'] = result_melt_df['property_category'].str[7:].str.strip()
result_melt_df['property_category'] = result_melt_df['property_category'].str[:7].str.strip()

# %%
# convert the secondary consideration to numeric and replace '-' with 0
result_melt_df['secondary_consideration'] = result_melt_df['secondary_consideration'].replace('-', 0)

# convert the consideration from per m2 to per ft2
result_melt_df['secondary_consideration'] = result_melt_df['secondary_consideration'].astype('float') / m2_to_ft2

# %%
# rearrange the columns
secondary_avg_price_district_output_df = result_melt_df[['Month','district','property_category','secondary_consideration']]

# %%
secondary_avg_price_district_output_df.to_csv('secondary_avg_price_district.csv', index = False, encoding = 'utf-8-sig')

# %% [markdown]
# ### Vacancy rate

# %%
vacancy_df = pd.read_csv(vacancy_rate_url, skiprows = 1, encoding = "utf-8")

# %%
vacancy_df.head()
# Out:
#    Year  Class A (Vacancy) - Unit  Class A (Vacancy) - %  \
# 0  1985                      9085                  0.037
# 1  1986                     10175                  0.039
# 2  1987                      7220                  0.026
# 3  1988                      5870                  0.021
# 4  1989                      6135                  0.021
#
#    Class B (Vacancy) - Unit  Class B (Vacancy) - %  Class C (Vacancy) - Unit  \
# 0                      7845                  0.032                      2420
# 1                      9170                  0.036                      2035
# 2                     10560                  0.039                      2255
# 3                      7845                  0.027                      3055
# 4                     17620                  0.057                      3450
#
#    Class C (Vacancy) - %  Class D (Vacancy) - Unit  Class D (Vacancy) - %  \
# 0                  0.044                      1930                  0.062
# ...

# %%
# create column name lists for unit and percent columns
unit_col_list = list()
percent_col_list = list()

for col in vacancy_df.columns:
    if 'year' in col.lower():
        unit_col_list.append(col)
        percent_col_list.append(col)
    elif 'unit' in col.lower():
        unit_col_list.append(col)
    elif '%' in col.lower():
        percent_col_list.append(col)

# %%
# create two separate dataframes for unit and percent columns
vacancy_unit_df = vacancy_df[unit_col_list]
vacancy_percent_df = vacancy_df[percent_col_list]

# %%
# unpivot to the table as long format
vacancy_unit_melt_df = pd.melt(vacancy_unit_df, id_vars=['Year'], var_name='vacancy_class', value_name='vacancy_unit')
vacancy_percent_df = pd.melt(vacancy_percent_df, id_vars=['Year'], var_name='vacancy_class', value_name='vacancy_percent')

# remove the extra string in the vacancy_class column in readable format 
vacancy_unit_melt_df['vacancy_class'] = vacancy_unit_melt_df['vacancy_class'].str.replace('(Vacancy) - Unit', '').str.strip()
vacancy_percent_df['vacancy_class'] = vacancy_percent_df['vacancy_class'].str.replace('(Vacancy) - %', '').str.strip()

# join the two dataframes together
vacancy_overall_df = pd.merge(vacancy_unit_melt_df, vacancy_percent_df, on=['Year', 'vacancy_class'])

# %%
vacancy_overall_df.head()
# Out:
#    Year vacancy_class  vacancy_unit  vacancy_percent
# 0  1985       Class A          9085            0.037
# 1  1986       Class A         10175            0.039
# 2  1987       Class A          7220            0.026
# 3  1988       Class A          5870            0.021
# 4  1989       Class A          6135            0.021

# %%
# export as csv file
vacancy_overall_df.to_csv('annual_vacancy_rate.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ### HOS 2nd market

# %%
hos_df = pd.read_csv('HOS_transaction_records_2020_2025.csv', encoding='utf-8')

# %%
hos_df.head()
# Out:
#    Location Court_Estate_Name Transaction_Price  Saleable_Floor_Area_sq_ft  \
# 0  Chai Wan   Cheerful Garden         5,700,000                        592
# 1  Chai Wan   Hang Tsui Court         3,750,000                        407
# 2  Chai Wan    Harmony Garden         4,500,000                        431
# 3  Chai Wan    Kai Tsui Court         3,880,000                        435
# 4  Chai Wan   Lok Hin Terrace         5,700,000                        580
#
#    Saleable_Floor_Area_sq_m Transaction_Price_sq_ft Transaction_Price_sq_m  \
# 0                        55                  9,628                 103,636
# 1                        38                  9,216                  99,206
# 2                        40                 10,452                 112,500
# 3                        40                  8,922                  96,040
# 4                        54                  9,825                 105,751
#
# ...

# %%
hos_df['Address'] = hos_df['Court_Estate_Name'] + ', ' + hos_df['Location'] + ', Hong Kong'

# %%
geolocator = Nominatim(user_agent="hk_dashboard")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# %%
## function to get the latitude and longitude of a location
def get_coordinates(location_name):

    try:
        location = geocode(location_name)
        
        if location:
            print("lat and long retrieved successfully")
            return pd.Series([location.latitude, location.longitude])

        else:
            print("location not found")
            return pd.Series([None, None])
        
    except Exception as e:
        print("error and location not found")
        return pd.Series([None, None])

# %%
hos_df[['Latitude','Longitude']] = hos_df['Address'].apply(get_coordinates)
# Out:
# lat and long retrieved successfully
# lat and long retrieved successfully
# lat and long retrieved successfully
# lat and long retrieved successfully
# lat and long retrieved successfully
# lat and long retrieved successfully
# lat and long retrieved successfully
# lat and long retrieved successfully
# location not found
# location not found
# lat and long retrieved successfully
# lat and long retrieved successfully
# lat and long retrieved successfully
# lat and long retrieved successfully
# lat and long retrieved successfully
# lat and long retrieved successfully
# lat and long retrieved successfully
# lat and long retrieved successfully
# lat and long retrieved successfully
# lat and long retrieved successfully
# location not found
# lat and long retrieved successfully
# lat and long retrieved successfully
# lat and long retrieved successfully
# lat and long retrieved successfully
# lat and long retrieved successfully
# lat and long retrieved successfully
# ...

# %%
hos_df.head()
# Out:
#    Location Court_Estate_Name Transaction_Price  Saleable_Floor_Area_sq_ft  \
# 0  Chai Wan   Cheerful Garden         5,700,000                        592
# 1  Chai Wan   Hang Tsui Court         3,750,000                        407
# 2  Chai Wan    Harmony Garden         4,500,000                        431
# 3  Chai Wan    Kai Tsui Court         3,880,000                        435
# 4  Chai Wan   Lok Hin Terrace         5,700,000                        580
#
#    Saleable_Floor_Area_sq_m Transaction_Price_sq_ft Transaction_Price_sq_m  \
# 0                        55                  9,628                 103,636
# 1                        38                  9,216                  99,206
# 2                        40                 10,452                 112,500
# 3                        40                  8,922                  96,040
# 4                        54                  9,825                 105,751
#
# ...

# %%
hos_df.to_csv('HOS_transaction_records_2020_2025_with_coordinates.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ### Import the manual found latitude location

# %%
lat_long_df = pd.read_csv("estate_with_coordinates.csv", encoding='utf-8')
hos_df = pd.read_csv('HOS_transaction_records_2020_2025_with_coordinates.csv', encoding='utf-8')

# %%
hos_lat_long_df = hos_df.merge(lat_long_df, left_on='Address', right_on='Address', how='left', suffixes=(None, '_backup'))

# %%
hos_df['Latitude'] = hos_lat_long_df['Latitude'].fillna(hos_lat_long_df['Latitude_backup'])
hos_df['Longitude'] = hos_lat_long_df['Longitude'].fillna(hos_lat_long_df['Longitude_backup'])

# %%
hos_df.to_csv('HOS_transaction_records_2020_2025_with_full_coordinates.csv', index=False, encoding='utf-8-sig')
